# %%
import pandas as pd

df = pd.read_csv('result.csv', sep=';;')

display(df.head())
# Out:
# C:\Users\LoZimmero\AppData\Local\Temp\ipykernel_27492\4037615946.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('result.csv', sep=';;')
#                          indicator indicator_type      label      user  \
# 0       https://mescomptes-bnp.fr/            url  #phishing  ecarlesi
# 1      http://alertsonarvest.help/            url  #phishing  ecarlesi
# 2           https://goritrest.xyz/            url  #phishing  ecarlesi
# 3     https://alertsonarvest.help/            url  #phishing  ecarlesi
# 4  https://alertsonarvest.help/?nd            url  #phishing  ecarlesi
#
#    twitter_link alienvault_date  hashlookup_date       kaspersky_date  \
# 0           NaN             NaN              NaN                  NaN
# ...
